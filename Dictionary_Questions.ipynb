# %% [markdown]
# 1. Create a empty Dictionary and check its Data type.

# %%
dict1={}
type(dict1)
# Out:
# dict

# %% [markdown]
# 2.Write a Python program to add a key to a dictionary
# Sample Dictionary : {0: 10, 1: 20}
#
# Expected Result : {0: 10, 1: 20, 2: 30}

# %%
dict1={'0':10,'1':20}
dict1[3]=30
dict1
# Out:
# {'0': 10, '1': 20, 3: 30}

# %% [markdown]
# 3.Write a Python script to concatenate following dictionaries to create a new one.
# Sample Dictionary :
#
# dic1={1:10, 2:20}
#
# dic2={3:30, 4:40}
#
# dic3={5:50,6:60}
#
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50,6:60}
dic1.update(dic2)
dic1.update(dic3)
dic1
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %% [markdown]
# 4.Write a program to create Dictionary and add new item in it.

# %%
dict2={0:10,1:20,2:30,4:50,5:60}
dict2
dict2[3]=40
dict2[6]=70
dict2[5]=80
dict2
# Out:
# {0: 10, 1: 20, 2: 30, 3: 40, 4: 50, 5: 80, 6: 70}

# %% [markdown]
# 5. Write a program to create Dictionary and delete the item at 3 index.

# %%
del dict2[3]
dict2
# Out:
# {0: 10, 1: 20, 2: 30, 4: 50, 5: 80, 6: 70}

# %% [markdown]
# 6. Write a program to create dictionary and delete last item from it.

# %%
l=list(dict2).pop(-1)
del dict2[l]

# %% [markdown]
# 7. Create a dictionary and print the item at 2nd index value.

# %%
dict2
dict2[1]
# Out:
# 20

# %% [markdown]
# 8. Create a Dictionary and change the range of key value .

# %%
dictt={'a':"one",'b':"two"}
dictt['b']="three"
dictt
# Out:
# {'a': 'one', 'b': 'three'}
