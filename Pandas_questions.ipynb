# %% [markdown]
# 1. Create 1-D array(series ) in pandas.

# %%
import pandas as pd 
df=pd.Series([1,2,3,4])
df
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# 2. Create a pandas series from a list

# %%
list1=["ser","new","key",123,12.5,'d']
df1=pd.Series(list1)
df1
# Out:
# 0     ser
# 1     new
# 2     key
# 3     123
# 4    12.5
# 5       d
# dtype: object

# %% [markdown]
# 3. Create a pandas series with user define index.

# %%
df1=pd.Series(['a','b','c','d'],index=[input(),input(),input(),input()])
df1
# Out:
# 1
# 3
# 5
# 7
# 1    a
# 3    b
# 5    c
# 7    d
# dtype: object

# %% [markdown]
# 4. Write a program to create Dataframe by Dictionay .

# %%
dict1={'Name':["Anvit","suraj","ayush","supriya"],'class':[1,5,4,3],'Place':["banglore","pune","mumbai","delhi"]}
df2=pd.DataFrame(dict1)
df2
# Out:
#       Name  class     Place
# 0    Anvit      1  banglore
# 1    suraj      5      pune
# 2    ayush      4    mumbai
# 3  supriya      3     delhi

# %% [markdown]
# 5. Create DataFrame and put index

# %%
data = [['ragh', 10], ['nil', 15], ['juli', 14]]
df3 = pd.DataFrame(data, index=["aa","ab","ac"],columns = ['Name', 'Age'])
df3
# Out:
#     Name  Age
# aa  ragh   10
# ab   nil   15
# ac  juli   14

# %% [markdown]
# 6.Accessing Data from Series with Position
# s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])

# %%
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
df4=pd.DataFrame(s)
print(df4)
df4.loc['a']
# Out:
#    0
# a  1
# b  2
# c  3
# d  4
# e  5
# 0    1
# Name: a, dtype: int64

# %% [markdown]
# 7.Create a DataFrame in which you have 2 columns(Name , Age) . And fill the data into this columns and use user define index

# %%
df4=pd.DataFrame(columns=["name","age"])
df4
df4.loc[0]=["Sk",20]
df4.loc[1]=["kk",25]
df4
# Out:
#   name age
# 0   Sk  20
# 1   kk  25

# %%
df4.index=["a1","a2"]
df4
# Out:
#    name age
# a1   Sk  20
# a2   kk  25
