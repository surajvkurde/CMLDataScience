# %% [markdown]
# **[Slide No.69]**
#
# 1. Write a function to print Hello world! .

# %%
def printH():
  print("Hello World!")

#printH function call
printH()
# Out:
# Hello World!

# %% [markdown]
# **[Slide No. 69]**
#
# 2. Write a function to print  Hello four times .

# %%
def printH(n):
  while(n>0):
    print("Hello!")
    n-=1

#printH function call
printH(4)
# Out:
# Hello!
# Hello!
# Hello!
# Hello!

# %% [markdown]
# **[Slide No. 69]**
#
# 3. Write a function to find the diff, add , mul of two numbers.

# %%
def arith(a,b):
  c=a+b
  print(c)
  c=a-b
  print(c)
  c=a*b
  print(c)

a=int(input())
b=int(input())
arith(a,b)
# Out:
# 10
# 2
# 12
# 8
# 20

# %% [markdown]
# **[Slide No. 69]**
#
#  4. Write the function to find the factorial of a number .

# %%
def factor(n):
  if(n==1 or n==0):
    return 1;
  else:
    return n*factor(n-1)

a=int(input())
print("factorial of ",a,"is",factor(a))
# Out:
# 5
# factorial of  5 is 120

# %% [markdown]
# **[Slide No. 69]**
#
# 5. Write a function to find the square of a number

# %%
def sqrN(n):
  print(n**2)

sqrN(5)
# Out:
# 25

# %% [markdown]
# **[Slide No. 73]**
#
# 6. Check the output of the program:
#
# myAdd = lambda x, y,z: x + y+z
#
# print (myAdd(6, 10,15))
#
# print (myAdd(7, 20,4))
#
# print (type(myAdd))

# %%
myAdd = lambda x, y,z: x + y+z

print (myAdd(6, 10,15))

print (myAdd(7, 20,4))

print (type(myAdd))
# Out:
# 31
# 31
# <class 'function'>
