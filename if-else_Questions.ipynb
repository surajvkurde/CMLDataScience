# %% [markdown]
# 1. write a program to Check wheather the age entered by user is above 18 or not?

# %%
age=int(input())
if age>=18:
  print("Age entered by user is 18 or above")
else:
  print("Age is below 18")
# Out:
# 18
# Age entered by user is 18 or above

# %% [markdown]
# 2.Write a program to check number entered is even or not ?

# %%
num=int(input())
if num%2==0:
  print("Number is Even ")
else:
  print("Number is odd")
# Out:
# 11
# Number is odd

# %% [markdown]
# 3.Write a program to print largest number from three given numbers.

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and b>c:
  print("Largest Number is : ",a)
elif b>a and b>c:
  print("Largest Number is : ",b)
else:
  print("Largest Number is : ",c)
# Out:
# 100
# 30
# 10
# Largest Number is :  100

# %% [markdown]
# 4.Write a program to check whether the user enter number is 10,50 and 100 .

# %%
a=int(input())
if a==10:
  print("User entered 10")
elif a==50:
  print("User entered 50")
elif a==100:
  print("User entered 100")
else:
  print("User input is other than 10, 50 and 100")
# Out:
# 50
# User entered 50

# %% [markdown]
# 5.Write a program to check given number is multiple of 6 or not .

# %%
n=int(input())
if n%6==0:
  print("Number is in multiple of 6")
else:
  print("number is not in mutiple of 6")
# Out:
# 30
# Number is in multiple of 6
